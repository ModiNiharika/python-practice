# %% [markdown]
# OPERATORS AND EXPRESSIONS

# %% [markdown]
# 1) Arithmetic Operators

# %% [markdown]
# Question 8:Write a python program which demonstrates the functionality of arithmetic operators

# %%
a=int(input("Enter value"))
b=int(input("Enter value"))
print("a+b=",a+b)
print("a-b=",a-b)
print("a*b=",a*b)
print("a/b=",a/b)
print("a//b=",a//b)
print("a % b =",a%b)
print("a**b=",a**b)
# Out:
# a+b= 11
# a-b= -3
# a*b= 28
# a/b= 0.5714285714285714
# a//b= 0
# a % b = 4
# a**b= 16384

# %% [markdown]
# Question 9 : Write a python program which will calculate the square root of the number

# %%
a=float(input("Enter value"))
r=a*0.5
print("Square root of number is ",r)
# Out:
# Square root of number is  2.0

# %% [markdown]
# Question 10 : Write a python program which will calculate the cube root of a number

# %%
a=float(input("Enter value"))
r=a*(1/3)
print("Cube root = ",r)
# Out:
# Cube root =  1.6666666666666665

# %% [markdown]
# Question 11 : Write a python program which will evaluate (a+b)^2

# %%
a=int(input("Enter a value"))
b=int(input("Enter a value"))
r=(a+b)**2
print(r)
# Out:
# 144

# %% [markdown]
# Question 12 : Write a python program which will implement a^m/a^n

# %%
a=int(input("Enter value of a"))
m=int(input("Enter value of m"))
n=int(input("Enter valuue of n"))
x=a**(m-n)
print(x)
# Out:
# 0.04

# %% [markdown]
# 2) Assignment Operators

# %% [markdown]
# Question 13 : Write a python program which will accept any two valued and swap them by using multiline assignment operator

# %%
a,b=int(input("Enter value of a")),int(input("Enter value of b"))
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 5 9
# 9 5

# %%
print(a,b)
a=a*b
b=a//b
a=a//b
print(a,b)
# Out:
# 5 9
# 9 5

# %%
print(a,b)
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# 9 5
# 5 9

# %% [markdown]
# 3) Relational Operators

# %% [markdown]
# Question 14 : Write a python program which demonstrate the concept of relational operators

# %%
a=int(input("Enter the value"))
b=int(input("enter the value"))
print("a>b=",a>b)
print("a<b=",a<b)
print("a==b=",a==b)
print("a!=b=",a!=b)
print("a>=b=",a>=b)
print("a<=b=",a<=b)
# Out:
# a>b= False
# a<b= True
# a==b= False
# a!=b= True
# a>=b= False
# a<=b= True

# %% [markdown]
# 4) Logical Operators

# %%
print(10>2 and 20<4)
print(10>2 or 20 >4)
print(not 10)
# Out:
# False
# True
# False

# %% [markdown]
# 5) Bitwise operators

# %%
a=10
b=3
print('left shift operator')
print(a<<b)
print(50*'-')
print('right shift operator')
print(a>>b)
print(50*'-')
print('Bitwise AND operator')
print(a & b)
print(50*'-')
print("Bitwise OR operator")
print(a | b)
print(50*'-')
print("Bitwise Complement Operator")
print(~a)
print(50*'-')
print('Bitwise XOR operator')
print(a^b)
print(50*'-')
# Out:
# left shift operator
# 80
# --------------------------------------------------
# right shift operator
# 1
# --------------------------------------------------
# Bitwise AND operator
# 2
# --------------------------------------------------
# Bitwise OR operator
# 11
# --------------------------------------------------
# Bitwise Complement Operator
# -11
# --------------------------------------------------
# Bitwise XOR operator
# 9
# --------------------------------------------------

# %% [markdown]
# 6) Membership Operator

# %%
s='PYTHON'
print('T' in s)
print('a' in s)
print('b' not in s)
print('y' in s)
# Out:
# True
# False
# True
# False

# %% [markdown]
# 7) Identity Operators

# %% [markdown]
# > In this if the two variables points to same keyword then they both are same .
# > In strings if two variables points to different things having same case , same order and same meaning stores in same address .
# > In floating point numbers if two variables points towards the same numbers are not same beacause they does not have certainity .
# > In integers if we give 0-256 and -1 to -5 it gives True if points towards same number because this data stored in registers otherwise returns False.
# > So basically all fundamental data types having same values in multiple objecs with single line assignment have same address .

# %%
l=[10,20]
a=l
print(l is a)
print(l is not a)
b=l.copy()
print(b is l)
print(b is not l)
a=200
b=200
a is b
# Out:
# True
# False
# False
# True
# True

# %% [markdown]
# PYTHON TERNARY OPERATOR

# %% [markdown]
# Question 14 : Write a python program which will accept 2 numeric values and find biggest among them

# %%
a= float(input("Enter value of a "))
b= float (input("Enter value of b"))
if(a>b):
    print(a,'is bigger than ',b)
else:
    print(b,'is bigger than',a)
# Out:
# 9.0 is bigger than 6.0

# %%
big=a if a>b else b
print(big,'is bigger')
# Out:
# 9.0 is bigger

# %%
big= a if a>b else b if b>a else 'Equal'
print(big)
# Out:
# 9.0

# %% [markdown]
# Question 15 : Write a python program which will accept a numerical integer value and decide whether positive , negative and zero

# %%
a= float(input("Enter the value"))
r='Positive' if(a>0) else 'Negative' if a<0 else 'Zero'
print(r)
# Out:
# Positive

# %% [markdown]
# Question 16 : Write a python program which will accept a numerical integer or float value and decide whether it is even or odd

# %%
a = float(input("Enter the value of a"))
r = 'Even' if (a%2==0) else 'Odd' 
print(r)
# Out:
# Even

# %% [markdown]
# Question 17 : Write a python program which will accept anyword and decide whether it is vowel word or not

# %%
a = input("Enter the text")
r = 'Vowel' if ('a' in a or 'e' in a or 'i' in a or 'o' in a or 'u' in a) else "Not Vowel"
print(r)
# Out:
# Not Vowel

# %% [markdown]
# Question 18 : Write a python program which will accept a string or value and check whether palindrome or not

# %%
a = input("Enter value").lower()
r = 'Palindrome' if(a==a[::-1]) else 'Not Palindrome' 
print(r)
# Out:
# Not Palindrome
