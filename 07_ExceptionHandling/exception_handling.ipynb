# %% [markdown]
# Exception Handling

# %% [markdown]
# Handling exceptions are nothing but converting technical error messages into user friendly error messages
#
# To do this process in python programming we have 5 keywords . They are
#
# 1) try      2) except       3) else     4) finally      5) raise

# %% [markdown]
# try : Exception monitoring block
#
# except : Exception processing block
#
# else : result generated block
#
# finally : resources relinquishing block

# %% [markdown]
# Program for performing division of two numbers

# %%
try :
    a = int(input())
    b = int(input())
    d = int(a)/int(b)   
except ValueError:
    print("Enter the correct value")
except ZeroDivisionError:
    print("Don't enter zero ")
else : 
    print(d)
finally:
    print("Excecution completed")
# Out:
# Enter the correct value
# Excecution completed

# %% [markdown]
# Various forms of except blocks

# %% [markdown]
# Form 1 :

# %%
a = int(input())
b = int(input())
try :
    c=a/b
except ZeroDivisionError:
    print("Don't enter zero in denominator")
else : 
    print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a = int(input())
#       2 b = int(input())
#       3 try :
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# Form 2 :

# %%
a = int(input())
b = int(input())
try :
    c=a/b
except (ZeroDivisionError, ValueError):
    print("Enter correct values")
else :
    print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 a = int(input())
# ----> 2 b = int(input())
#       3 try :
#       4     c=a/b
#
# ValueError: invalid literal for int() with base 10: 'i'
